# %% [markdown]
# # 研究流程方案推荐
# > 一篇论文踩过的坑

# %% [markdown]
# ## 文献调研
# 1. Notion,markdown 之类记笔记
# 2. 文献管理 Zotero
#     写开题报告 毕业论文, 往Word里插入文献特别方便!  详情请查阅[科研工具技能表](https://github.com/MLNBA-Lab/DataCollection2Public/blob/main/%E7%A7%91%E7%A0%94%E6%96%B9%E6%B3%95%E5%8F%8A%E5%B7%A5%E5%85%B7/%E7%A7%91%E7%A0%94%E5%B7%A5%E5%85%B7%E5%8F%8A%E6%8A%80%E8%83%BD%E8%A1%A8%E6%8E%A8%E8%8D%90.md)

# %% [markdown]
# 经历了大量的文献调研之后,你终于找到了一个不错的idea,打算开始做实验,写论文....

# %% [markdown]
# ## 开始你的工程
# 使用github新建一个仓库

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 最好为每一个工程独立创建一个环境

# %% [markdown]
# ### Python:
# 1. Anaconda 创建环境
#
# 2. pip install
#   conda install (尽量只用pip install, 这样pip导出的依赖比较干净)
#
# 3.导出环境依赖
#
#      conda env export > env.yaml
#      pip freeze > requirements.txt
#
# 4.重建环境
# 这样当前环境安装的包就被保存在environment.yaml中。如果想copy环境，就可以根据别人提供的.yaml文件进行环境复现：
#
#     conda env create -f env.yaml
#
# 但是只是移植了conda install直接安装的包，pip安装的包还需要 pip install -r requirements.txt 重新安装。

# %% [markdown]
# #### Julia:
# activate .   当前文件夹
#
# https://cn.julialang.org/JuliaZH.jl/latest/stdlib/Pkg/#Creating-your-own-projects
#
#    1. 这样每个Julia工程 文件夹下会维护一个依赖库文件 Manifest.toml
#
#    2.别人git clone 你的工程的时候,可以快速通过使用instantiate命令[还原依赖环境](https://cn.julialang.org/JuliaZH.jl/latest/stdlib/Pkg/#%E4%BD%BF%E7%94%A8%E5%88%AB%E4%BA%BA%E7%9A%84%E9%A1%B9%E7%9B%AE)

# %% [markdown]
# ### 然后你开始用一个编辑器写你的代码.....

# %% [markdown]
# 最好有一个开发文档...

# %% [markdown]
# #### 基本的工程文件结构:(Julia  科学计算 DrWatson助手)
# https://juliadynamics.github.io/DrWatson.jl/dev/project/#Default-Project-Setup-1
#
#     │projectdir          <- Project's main folder. It is initialized as a Git
#     │                       repository with a reasonable .gitignore file.
#     │
#     ├── _research        <- WIP scripts, code, notes, comments,
#     │   |                   to-dos and anything in an alpha state.
#     │   └── tmp          <- Temporary data folder.
#     │
#     ├── data             <- **Immutable and add-only!**
#     │   ├── sims         <- Data resulting directly from simulations.
#     │   ├── exp_pro      <- Data from processing experiments.
#     │   └── exp_raw      <- Raw experimental data.
#     │
#     ├── plots            <- Self-explanatory.
#     ├── notebooks        <- Jupyter, Weave or any other mixed media notebooks.
#     │
#     ├── papers           <- Scientific papers resulting from the project.
#     │
#     ├── scripts          <- Various scripts, e.g. simulations, plotting, analysis,
#     │   │                   The scripts use the `src` folder for their base code.
#     │   └── intro.jl     <- Simple file that uses DrWatson and uses its greeting.
#     │
#     ├── src              <- Source code for use in this project. Contains functions,
#     │                       structures and modules that are used throughout
#     │                       the project and in multiple scripts.
#     │
#     ├── README.md        <- Optional top-level README for anyone using this project.
#     ├── .gitignore       <- by default ignores _research, data, plots, videos,
#     │                       notebooks and latex-compilation related files.
#     │
#     ├── Manifest.toml    <- Contains full list of exact package versions used currently.
#     └── Project.toml     <- Main project file, allows activation and installation.
#                             Includes DrWatson by default.

# %% [markdown]
# ### 每次更新代码,请注意git版本控制
# ![image.png](attachment:image.png)

# %% [markdown]
# 每次更新代码,请注意git版本控制
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### 注意:  github push之前,注意取消不必要的中间文件
# 比如latex编译过程中生成的文件
#
# 比如vscode 工作区配置文件,GitHub同步后,在另一台电脑同步配置文件会出问题

# %% [markdown]
# ### 注意
# #### 为每个函数写docstring
# 不然几周之后 你可能就不知道自己代码是干了啥
#
# https://docs.juliacn.com/latest/manual/documentation/
#
# 遵守Julia代码规范可以写出性能更好的代码,
#
# https://docs.juliacn.com/latest/manual/style-guide/
#
# https://docs.juliacn.com/latest/manual/workflow-tips/
# #### 注意命名规范

# %% [markdown]
# 迭代了N个版本,经历了各种实验之后,
#
# 中间改动了N次方法,可能和你一开始的想法截然不同,
#
# 最终
# 你终于得到了你觉得满意的结果

# %% [markdown]
# ## 你开始写paper了.....

# %% [markdown]
# ## 你需要学习Latex  详情请查阅[科研工具技能表](https://github.com/MLNBA-Lab/DataCollection2Public/blob/main/%E7%A7%91%E7%A0%94%E6%96%B9%E6%B3%95%E5%8F%8A%E5%B7%A5%E5%85%B7/%E7%A7%91%E7%A0%94%E5%B7%A5%E5%85%B7%E5%8F%8A%E6%8A%80%E8%83%BD%E8%A1%A8%E6%8E%A8%E8%8D%90.md)
# 我用的是TexLive + vscode

# %% [markdown]
# 之前组会讲的[论文写作组会记录](https://github.com/MLNBA-Lab/DataCollection2Public/blob/main/%E7%A7%91%E7%A0%94%E6%96%B9%E6%B3%95%E5%8F%8A%E5%B7%A5%E5%85%B7/%E8%AE%BA%E6%96%87%E5%86%99%E4%BD%9C%E7%BB%8F%E9%AA%8C%20%E7%BB%84%E4%BC%9A%E8%AE%B0%E5%BD%95.md)

# %% [markdown]
# 一般先写方法 实验...

# %% [markdown]
# #### 组内画图仓库 [画图](https://github.com/MLNBA-Lab/PlotsCode/blob/main/%E8%AE%BA%E6%96%87%E7%BB%98%E5%9B%BE%E5%A4%A7%E7%BB%84%E4%BC%9Amatplotlib%20Julia%20Plots.ipynb)
#
# 所有的画图代码 最好用jupyter 保存源码和图片,这样你可以随时在GitHub上,用浏览器查看
#
# 所有图片最好保存为 pdf
#
# 表格最好是三线表
# 所有的画图代码 最好

# %% [markdown]
# ## 经过频繁的和导师交流,修改之后, 你的论文投稿了....

# %% [markdown]
# ### 完成了吗?

# %% [markdown]
# ### 当然没有..

# %% [markdown]
# ### 漫长的等待后,你可能会拿到一堆修改意见,然后你再改, 你也可能会被拒....

# %% [markdown]
# ### 祝你科研愉快
